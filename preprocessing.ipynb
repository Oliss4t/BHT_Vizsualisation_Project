# %%
import pandas as pd
import pycountry
import missingno as msno

# %% [markdown]
# ## Preprocessing Each Data into Same Format Columns

# %%
data2015 = pd.read_csv('./data/happy/2015.csv')
data2015['Year'] = 2015

data2016 = pd.read_csv('./data/happy/2016.csv')
data2016['Year'] = 2016

data2017 = pd.read_csv('./data/happy/2017.csv')
data2017 = data2017.rename(columns = {'Happiness.Rank':'Happiness Rank', 'Happiness.Score' : 'Happiness Score',
                                      'Economy..GDP.per.Capita.' : 'Economy (GDP per Capita)', 'Health..Life.Expectancy.' : 'Health (Life Expectancy)',
                                      'Trust..Government.Corruption.' : 'Trust (Government Corruption)', 'Dystopia.Residual' : 'Dystopia Residual'})
data2017['Year'] = 2017


data2018 = pd.read_csv('./data/happy/2018.csv')
data2018 = data2018.rename(columns = {'Overall rank':'Happiness Rank', 'Country or region' : 'Country', 'Score' : 'Happiness Score',
                                      'GDP per capita' : 'Economy (GDP per Capita)', 'Social support' : 'Family',
                                      'Healthy life expectancy' : 'Health (Life Expectancy)','Freedom to make life choices' : 'Freedom',
                                      'Perceptions of corruption' : 'Trust (Government Corruption)'})
data2018['Year'] = 2018


data2019 = pd.read_csv('./data/happy/2019.csv')
data2019 = data2019.rename(columns = {'Overall rank':'Happiness Rank', 'Country or region' : 'Country', 'Score' : 'Happiness Score',
                                      'GDP per capita' : 'Economy (GDP per Capita)', 'Social support' : 'Family',
                                      'Healthy life expectancy' : 'Health (Life Expectancy)','Freedom to make life choices' : 'Freedom'
                                     , 'Perceptions of corruption' : 'Trust (Government Corruption)'})
data2019['Year'] = 2019

data2020 = pd.read_csv('./data/happy/2020.csv',sep=';')
data2020['Happiness Rank'] =  range(1, len(data2020.index)+1)
data2020.drop('Generosity', axis=1,inplace=True)
data2020 = data2020.rename(columns = {'Country name' : 'Country', 'Ladder score' : 'Happiness Score',
                                      'Explained by: Log GDP per capita' : 'Economy (GDP per Capita)', 'Explained by: Social support' : 'Family', 'Explained by: Healthy life expectancy' : 'Health (Life Expectancy)',
                                      'Explained by: Freedom to make life choices' : 'Freedom', 'Explained by: Generosity':'Generosity',
                                      'Explained by: Perceptions of corruption' : 'Trust (Government Corruption)'})
data2020['Year'] = 2020
# data2020.reindex(columns=['Country', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)',
#                                    'Family', 'Health (Life Expectancy)', 'Freedom','Trust (Government Corruption)',
#                                    'Generosity', 'Year'])
#data2020 = data2020.reset_index(drop=True)

data2021 = pd.read_csv('./data/happy/2021.csv')
data2021['Happiness Rank'] =  range(1, len(data2021.index)+1)
data2021.drop('Generosity', axis=1, inplace=True)
data2021 = data2021.rename(columns = {'Country name' : 'Country', 'Ladder score' : 'Happiness Score',
                                        'Explained by: Log GDP per capita' : 'Economy (GDP per Capita)', 'Explained by: Social support' : 'Family', 'Explained by: Healthy life expectancy' : 'Health (Life Expectancy)',
                                      'Explained by: Freedom to make life choices' : 'Freedom', 'Explained by: Generosity':'Generosity',
                                      'Explained by: Perceptions of corruption' : 'Trust (Government Corruption)'})
data2021['Year'] = 2021
# data2021.reindex(columns=['Country', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)',
#                                    'Family', 'Health (Life Expectancy)', 'Freedom','Trust (Government Corruption)',
#                                    'Generosity', 'Year'])
#data2021 = data2021.reset_index(drop=True)

data2022 = pd.read_csv('./data/happy/2022.csv')
data2022['Happiness Rank'] =  range(1, len(data2022.index)+1)
#data2022.drop('Generosity', axis=1, inplace=True)
data2022 = data2020.rename(columns = {'Country name' : 'Country', 'Ladder score' : 'Happiness Score',
                                      'Explained by: Log GDP per capita' : 'Economy (GDP per Capita)', 'Explained by: Social support' : 'Family', 'Explained by: Healthy life expectancy' : 'Health (Life Expectancy)',
                                      'Explained by: Freedom to make life choices' : 'Freedom', 'Explained by: Generosity':'Generosity',
                                      'Explained by: Perceptions of corruption' : 'Trust (Government Corruption)'})
data2022['Year'] = 2022
# data2022.reindex(columns=['Country', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)',
#                                    'Family', 'Health (Life Expectancy)', 'Freedom','Trust (Government Corruption)',
#                                    'Generosity', 'Year'])
#data2022 = data2022.reset_index(drop=True)

data2020
# Out:
#                       Country  Regional indicator  Happiness Score  \
# 0                     Finland      Western Europe           7.8087
# 1                     Denmark      Western Europe           7.6456
# 2                 Switzerland      Western Europe           7.5599
# 3                     Iceland      Western Europe           7.5045
# 4                      Norway      Western Europe           7.4880
# ..                        ...                 ...              ...
# 148  Central African Republic  Sub-Saharan Africa           3.4759
# 149                    Rwanda  Sub-Saharan Africa           3.3123
# 150                  Zimbabwe  Sub-Saharan Africa           3.2992
# 151               South Sudan  Sub-Saharan Africa           2.8166
# 152               Afghanistan          South Asia           2.5669
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                          0.031156      7.869766      7.747634
# ...

# %% [markdown]
# ## Store Each Data from to 2015 - 2022 into New Data Frame

# %%
datarank = pd.DataFrame(columns = ['Country', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)',
                                   'Family', 'Health (Life Expectancy)', 'Freedom','Trust (Government Corruption)',
                                   'Generosity', 'Year'])
n = [data2015, data2016, data2017, data2018, data2019,data2020, data2021, data2022]


for i in n:
    datarank = datarank.append(i[['Country', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)',
                                   'Family', 'Health (Life Expectancy)', 'Freedom','Trust (Government Corruption)',
                                   'Generosity', 'Year']], ignore_index = 'True')
# Out:
# C:\Users\henninta\AppData\Local\Temp\ipykernel_14980\85733756.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   datarank = datarank.append(i[['Country', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)',
# C:\Users\henninta\AppData\Local\Temp\ipykernel_14980\85733756.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   datarank = datarank.append(i[['Country', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)',
# C:\Users\henninta\AppData\Local\Temp\ipykernel_14980\85733756.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   datarank = datarank.append(i[['Country', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)',
# ...

# %%
df_country_region_mapping_2022 = data2022.loc[:, ['Country', 'Regional indicator']].rename(columns = {'Country' : 'Country', 'Regional indicator' : 'Region 1'})
df_country_region_mapping_2015 = data2015.loc[:, ['Country', 'Region']].rename(columns = {'Country' : 'Country', 'Region' : 'Region 2'})
df_country_region_mapping_2016 = data2016.loc[:, ['Country', 'Region']].rename(columns = {'Country' : 'Country', 'Region' : 'Region 3'})

df_country_region_mapping = pd.merge(df_country_region_mapping_2022, df_country_region_mapping_2015, how='left', on=["Country"])
df_country_region_mapping = pd.merge(df_country_region_mapping, df_country_region_mapping_2016, how='left', on=["Country"])
df_country_region_mapping['Region'] =df_country_region_mapping[['Region 1', 'Region 2', 'Region 3']].bfill(axis=1).iloc[:, 0]
df_country_region_mapping.drop(['Region 1', 'Region 2', 'Region 3'], axis=1, inplace=True)
df_country_region_mapping
# Out:
#                       Country              Region
# 0                     Finland      Western Europe
# 1                     Denmark      Western Europe
# 2                 Switzerland      Western Europe
# 3                     Iceland      Western Europe
# 4                      Norway      Western Europe
# ..                        ...                 ...
# 148  Central African Republic  Sub-Saharan Africa
# 149                    Rwanda  Sub-Saharan Africa
# 150                  Zimbabwe  Sub-Saharan Africa
# 151               South Sudan  Sub-Saharan Africa
# 152               Afghanistan          South Asia
#
# [153 rows x 2 columns]

# %%
countries = {}
for country in pycountry.countries:
    countries[country.name] = country.alpha_2

df_country_region_mapping['Country Code'] = df_country_region_mapping.apply(lambda row : countries.get(row['Country'], 'Unknown code'), axis = 1)
df_country_region_mapping
# Out:
#                       Country              Region Country Code
# 0                     Finland      Western Europe           FI
# 1                     Denmark      Western Europe           DK
# 2                 Switzerland      Western Europe           CH
# 3                     Iceland      Western Europe           IS
# 4                      Norway      Western Europe           NO
# ..                        ...                 ...          ...
# 148  Central African Republic  Sub-Saharan Africa           CF
# 149                    Rwanda  Sub-Saharan Africa           RW
# 150                  Zimbabwe  Sub-Saharan Africa           ZW
# 151               South Sudan  Sub-Saharan Africa           SS
# 152               Afghanistan          South Asia           AF
#
# [153 rows x 3 columns]

# %%
pd_happy = pd.merge(datarank, df_country_region_mapping, how='left', on=["Country"])

# %%
pd_happy[(pd_happy['Region'].isnull())]
# Out:
#                       Country Happiness Rank  Happiness Score  \
# 21                       Oman             22            6.853
# 27                      Qatar             28            6.611
# 37                     Taiwan             38            6.298
# 39                   Suriname             40            6.269
# 71                  Hong Kong             72            5.474
# 78                     Bhutan             79            5.253
# 90          Somaliland region             91            5.057
# 117                     Sudan            118            4.550
# 125                  Djibouti            126            4.369
# 136                    Angola            137            4.033
# 155                     Syria            156            3.006
# 172               Puerto Rico             15            7.039
# 192                    Taiwan             34            6.379
# 193                     Qatar             36            6.375
# ...

# %%
pd_happy.to_csv("./data/happy/2015_2022.csv")
pd_happy
# Out:
#                        Country Happiness Rank  Happiness Score  \
# 0                  Switzerland              1           7.5870
# 1                      Iceland              2           7.5610
# 2                      Denmark              3           7.5270
# 3                       Norway              4           7.5220
# 4                       Canada              5           7.4270
# ...                        ...            ...              ...
# 1232  Central African Republic            149           3.4759
# 1233                    Rwanda            150           3.3123
# 1234                  Zimbabwe            151           3.2992
# 1235               South Sudan            152           2.8166
# 1236               Afghanistan            153           2.5669
#
#       Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                     1.396510  1.349510                  0.941430  0.665570
# ...

# %%
pd_coffee = pd.read_csv("./data/coffee_consumption.csv")
pd_alcohol = pd.read_csv("./data/alcohol-consumption-vs-gdp-per-capita.csv")
pd_smoke = pd.read_csv("./data/share-of-adults-who-smoke.csv")
pd_internet = pd.read_csv("./data/internet_usage.csv", sep= ';')

# %%
#pd_coffee # only 5 countries for 2015 to 2018

# %%
pd_alcohol
# Out:
#               Entity      Code  Year  \
# 0           Abkhazia  OWID_ABK  2015
# 1        Afghanistan       AFG  2010
# 2        Afghanistan       AFG  2015
# 3        Afghanistan       AFG  2018
# 4        Afghanistan       AFG  2002
# ...              ...       ...   ...
# 57079       Zimbabwe       ZWE  1987
# 57080       Zimbabwe       ZWE  1988
# 57081       Zimbabwe       ZWE  1989
# 57082       Zimbabwe       ZWE  2021
# 57083  Åland Islands       ALA  2015
#
#        Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  \
# 0                                                    NaN
# 1                                                   0.21
# 2                                                   0.21
# 3                                                   0.21
# 4                                                    NaN
# ...                                                  ...
# 57079                                                NaN
# ...

# %%
pd_happy_alcohol = pd.merge(pd_happy, pd_alcohol, how='left', left_on=["Country",'Year'], right_on=["Entity",'Year'])
pd_happy_alcohol.drop(['Entity', 'GDP per capita, PPP (constant 2017 international $)', 'Continent'], axis=1, inplace=True)
pd_happy_alcohol
# Out:
#                        Country Happiness Rank  Happiness Score  \
# 0                  Switzerland              1           7.5870
# 1                      Iceland              2           7.5610
# 2                      Denmark              3           7.5270
# 3                       Norway              4           7.5220
# 4                       Canada              5           7.4270
# ...                        ...            ...              ...
# 1232  Central African Republic            149           3.4759
# 1233                    Rwanda            150           3.3123
# 1234                  Zimbabwe            151           3.2992
# 1235               South Sudan            152           2.8166
# 1236               Afghanistan            153           2.5669
#
#       Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                     1.396510  1.349510                  0.941430  0.665570
# ...

# %%
pd_smoke
# Out:
#                            Entity Code  Year  \
# 0     Africa Eastern and Southern  NaN  2007
# 1     Africa Eastern and Southern  NaN  2010
# 2     Africa Eastern and Southern  NaN  2012
# 3     Africa Eastern and Southern  NaN  2014
# 4     Africa Eastern and Southern  NaN  2016
# ...                           ...  ...   ...
# 1159                     Zimbabwe  ZWE  2010
# 1160                     Zimbabwe  ZWE  2012
# 1161                     Zimbabwe  ZWE  2014
# 1162                     Zimbabwe  ZWE  2016
# 1163                     Zimbabwe  ZWE  2018
#
#       Prevalence of current tobacco use (% of adults)
# 0                                           19.292770
# 1                                           17.881628
# 2                                           16.973612
# 3                                           16.141819
# 4                                           15.391768
# ...                                               ...
# ...

# %%
filtered_pd_smoke = pd_smoke[pd_smoke['Code'].notnull()]
filtered_pd_smoke
# Out:
#         Entity Code  Year  Prevalence of current tobacco use (% of adults)
# 12     Albania  ALB  2007                                             32.0
# 13     Albania  ALB  2010                                             31.1
# 14     Albania  ALB  2012                                             30.5
# 15     Albania  ALB  2014                                             30.1
# 16     Albania  ALB  2016                                             29.7
# ...        ...  ...   ...                                              ...
# 1159  Zimbabwe  ZWE  2010                                             15.6
# 1160  Zimbabwe  ZWE  2012                                             15.2
# 1161  Zimbabwe  ZWE  2014                                             14.7
# 1162  Zimbabwe  ZWE  2016                                             14.3
# 1163  Zimbabwe  ZWE  2018                                             13.9
#
# [894 rows x 4 columns]

# %%
pd_happy_alcohol_smoke = pd.merge(pd_happy_alcohol, filtered_pd_smoke, how='left', left_on=["Code",'Year'], right_on=["Code",'Year'])
pd_happy_alcohol_smoke.drop(['Entity'], axis=1, inplace=True)
pd_happy_alcohol_smoke
# Out:
#                        Country Happiness Rank  Happiness Score  \
# 0                  Switzerland              1           7.5870
# 1                      Iceland              2           7.5610
# 2                      Denmark              3           7.5270
# 3                       Norway              4           7.5220
# 4                       Canada              5           7.4270
# ...                        ...            ...              ...
# 1232  Central African Republic            149           3.4759
# 1233                    Rwanda            150           3.3123
# 1234                  Zimbabwe            151           3.2992
# 1235               South Sudan            152           2.8166
# 1236               Afghanistan            153           2.5669
#
#       Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                     1.396510  1.349510                  0.941430  0.665570
# ...

# %%
pd_happy_alcohol_smoke[(pd_happy_alcohol_smoke['Prevalence of current tobacco use (% of adults)'].notnull())]
# Out:
#          Country Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 158      Denmark              1            7.526                   1.44178
# 159  Switzerland              2            7.509                   1.52733
# 160      Iceland              3            7.501                   1.42666
# 161       Norway              4            7.498                   1.57744
# 162      Finland              5            7.413                   1.40598
# ..           ...            ...              ...                       ...
# 618      Liberia            149            3.495                   0.07600
# 620       Rwanda            151            3.408                   0.33200
# 621        Yemen            152            3.355                   0.44200
# 622     Tanzania            153            3.303                   0.45500
# 625      Burundi            156            2.905                   0.09100
#
#       Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
pd_internet
# Out:
#                     Country Name Country Code       2015       2016  \
# 0                          Aruba          ABW  88.661227  93.542454
# 1    Africa Eastern and Southern          AFE  14.625664  15.894355
# 2                    Afghanistan          AFG   8.260000  11.000000
# 3     Africa Western and Central          AFW  18.192287  20.926632
# 4                         Angola          AGO  22.000000  23.200000
# ..                           ...          ...        ...        ...
# 261                       Kosovo          XKX        NaN        NaN
# 262                  Yemen, Rep.          YEM  24.085409  24.579208
# 263                 South Africa          ZAF  51.919116  54.000000
# 264                       Zambia          ZMB   8.800000  10.300000
# 265                     Zimbabwe          ZWE  22.742818  23.119989
#
#           2017       2018       2019       2020
# 0    97.170000        NaN        NaN        NaN
# 1    18.240060  21.700695  24.304658  27.350308
# ...

# %%
pd_internet_unpivot = pd.melt(pd_internet, id_vars='Country Code', value_vars=['2015', '2016', '2017', '2018', '2019', '2020'], var_name='Year', value_name= 'Individuals using the Internet (% of population)')
pd_internet_unpivot = pd_internet_unpivot.rename(columns = {'Country Code' : 'Code'})
pd_internet_unpivot['Year'] = pd_internet_unpivot['Year'].astype(int)
pd_internet_unpivot
# Out:
#      Code  Year  Individuals using the Internet (% of population)
# 0     ABW  2015                                         88.661227
# 1     AFE  2015                                         14.625664
# 2     AFG  2015                                          8.260000
# 3     AFW  2015                                         18.192287
# 4     AGO  2015                                         22.000000
# ...   ...   ...                                               ...
# 1591  XKX  2020                                               NaN
# 1592  YEM  2020                                               NaN
# 1593  ZAF  2020                                         70.000000
# 1594  ZMB  2020                                         19.800000
# 1595  ZWE  2020                                         29.300000
#
# [1596 rows x 3 columns]

# %%
pd_happy_alcohol_smoke_internet = pd.merge(pd_happy_alcohol_smoke, pd_internet_unpivot, how='left', left_on=['Code','Year'], right_on=['Code','Year'])
pd_happy_alcohol_smoke_internet
# Out:
#                        Country Happiness Rank  Happiness Score  \
# 0                  Switzerland              1           7.5870
# 1                      Iceland              2           7.5610
# 2                      Denmark              3           7.5270
# 3                       Norway              4           7.5220
# 4                       Canada              5           7.4270
# ...                        ...            ...              ...
# 1232  Central African Republic            149           3.4759
# 1233                    Rwanda            150           3.3123
# 1234                  Zimbabwe            151           3.2992
# 1235               South Sudan            152           2.8166
# 1236               Afghanistan            153           2.5669
#
#       Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                     1.396510  1.349510                  0.941430  0.665570
# ...

# %%
pd_happy_alcohol_smoke_internet[(pd_happy_alcohol_smoke_internet['Individuals using the Internet (% of population)'].notnull())]
# Out:
#                       Country Happiness Rank  Happiness Score  \
# 0                 Switzerland              1           7.5870
# 1                     Iceland              2           7.5610
# 2                     Denmark              3           7.5270
# 3                      Norway              4           7.5220
# 4                      Canada              5           7.4270
# ..                        ...            ...              ...
# 930  Central African Republic            149           3.4759
# 931                    Rwanda            150           3.3123
# 932                  Zimbabwe            151           3.2992
# 933               South Sudan            152           2.8166
# 934               Afghanistan            153           2.5669
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.396510  1.349510                  0.941430  0.665570
# ...

# %%
pd_happy_alcohol_smoke_internet.rename(columns = {'Happiness Score':'Happiness','Economy (GDP per Capita)':'Economy',
                                                              'Health (Life Expectancy)':'Health','Trust (Government Corruption)':'Trust',
                                                              'Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)':'Alcohol',
                                                              'Population (historical estimates)':'Population','Prevalence of current tobacco use (% of adults)':'Tobacco',
                                                              'Individuals using the Internet (% of population)':'Internet'
                                                              }, inplace = True)

fig = msno.matrix(pd_happy_alcohol_smoke_internet)
fig_copy = fig.get_figure()
fig_copy.savefig('full_data_missing_values.png', bbox_inches = 'tight')

# %%
msno.matrix(pd_happy_alcohol_smoke_internet[(pd_happy_alcohol_smoke_internet.Year == 2015)])
# Out:
# <AxesSubplot:>

# %%
msno.matrix(pd_happy_alcohol_smoke_internet[(pd_happy_alcohol_smoke_internet.Year == 2016)])
# Out:
# <AxesSubplot:>

# %%
fig = msno.matrix(pd_happy_alcohol_smoke_internet[(pd_happy_alcohol_smoke_internet.Year == 2017)])


fig_copy = fig.get_figure()
fig_copy.savefig('2017_missing_values.png', bbox_inches = 'tight')

# %%
fig = msno.matrix(pd_happy_alcohol_smoke_internet[(pd_happy_alcohol_smoke_internet.Year == 2018)])
fig_copy = fig.get_figure()
fig_copy.savefig('2018_missing_values.png', bbox_inches = 'tight')

# %%
pd_happy_alcohol_smoke_internet_2018 = pd_happy_alcohol_smoke_internet[(pd_happy_alcohol_smoke_internet.Year == 2018)]

# %%
pd_happy_alcohol_smoke_internet_2018_no_nan = pd_happy_alcohol_smoke_internet_2018.dropna()
pd_happy_alcohol_smoke_internet_2018_no_nan
# Out:
#          Country Happiness Rank  Happiness  Economy  Family  Health  Freedom  \
# 470      Finland              1      7.632    1.305   1.592   0.874    0.681
# 471       Norway              2      7.594    1.456   1.582   0.861    0.686
# 472      Denmark              3      7.555    1.351   1.590   0.868    0.683
# 473      Iceland              4      7.495    1.343   1.644   0.914    0.677
# 474  Switzerland              5      7.487    1.420   1.549   0.927    0.660
# ..           ...            ...        ...      ...     ...     ...      ...
# 617        Haiti            148      3.582    0.315   0.714   0.289    0.025
# 618      Liberia            149      3.495    0.076   0.858   0.267    0.419
# 620       Rwanda            151      3.408    0.332   0.896   0.400    0.636
# 622     Tanzania            153      3.303    0.455   0.991   0.381    0.481
# 625      Burundi            156      2.905    0.091   0.627   0.145    0.065
#
# ...

# %%
msno.matrix(pd_happy_alcohol_smoke_internet[(pd_happy_alcohol_smoke_internet.Year == 2019)])
# Out:
# <AxesSubplot:>

# %%
msno.matrix(pd_happy_alcohol_smoke_internet[(pd_happy_alcohol_smoke_internet.Year == 2020)])
# Out:
# <AxesSubplot:>

# %%
msno.matrix(pd_happy_alcohol_smoke_internet[(pd_happy_alcohol_smoke_internet.Year == 2021)])
# Out:
# <AxesSubplot:>

# %%
msno.matrix(pd_happy_alcohol_smoke_internet[(pd_happy_alcohol_smoke_internet.Year == 2022)])
# Out:
# <AxesSubplot:>

# %%
pd_happy_alcohol_smoke_internet.to_csv("./data/preprocessed_data.csv")

# %%
pd_happy_alcohol_smoke_internet_2018_no_nan
# Out:
#          Country Happiness Rank  Happiness  Economy  Family  Health  Freedom  \
# 470      Finland              1      7.632    1.305   1.592   0.874    0.681
# 471       Norway              2      7.594    1.456   1.582   0.861    0.686
# 472      Denmark              3      7.555    1.351   1.590   0.868    0.683
# 473      Iceland              4      7.495    1.343   1.644   0.914    0.677
# 474  Switzerland              5      7.487    1.420   1.549   0.927    0.660
# ..           ...            ...        ...      ...     ...     ...      ...
# 617        Haiti            148      3.582    0.315   0.714   0.289    0.025
# 618      Liberia            149      3.495    0.076   0.858   0.267    0.419
# 620       Rwanda            151      3.408    0.332   0.896   0.400    0.636
# 622     Tanzania            153      3.303    0.455   0.991   0.381    0.481
# 625      Burundi            156      2.905    0.091   0.627   0.145    0.065
#
# ...

# %%
pd_happy_alcohol_smoke_internet_2018_no_nan.rename(columns = {'Happiness Score':'Happiness','Economy (GDP per Capita)':'Economy',
                                                              'Health (Life Expectancy)':'Health','Trust (Government Corruption)':'Trust',
                                                              'Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)':'Alcohol',
                                                              'Population (historical estimates)':'Population','Prevalence of current tobacco use (% of adults)':'Tobacco',
                                                              'Individuals using the Internet (% of population)':'Internet'
                                                              }, inplace = True)
pd_happy_alcohol_smoke_internet_2018_no_nan.to_csv("./data/preprocessed_data_2018_no_nan.csv", index=False)
# Out:
# C:\Users\henninta\AppData\Local\Temp\ipykernel_14980\384648659.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd_happy_alcohol_smoke_internet_2018_no_nan.rename(columns = {'Happiness Score':'Happiness','Economy (GDP per Capita)':'Economy',

# %%
pd_happy_alcohol_smoke_internet = pd.read_csv("./data/preprocessed_data.csv")

# %%
pd_happy_alcohol_smoke_internet.drop(['Country Code','Code','Alcohol','Population','Tobacco','Internet'], axis=1, inplace=True)
pd_happy_alcohol_smoke_internet
# Out:
#       Unnamed: 0                   Country  Happiness Rank  Happiness  \
# 0              0               Switzerland               1     7.5870
# 1              1                   Iceland               2     7.5610
# 2              2                   Denmark               3     7.5270
# 3              3                    Norway               4     7.5220
# 4              4                    Canada               5     7.4270
# ...          ...                       ...             ...        ...
# 1232        1232  Central African Republic             149     3.4759
# 1233        1233                    Rwanda             150     3.3123
# 1234        1234                  Zimbabwe             151     3.2992
# 1235        1235               South Sudan             152     2.8166
# 1236        1236               Afghanistan             153     2.5669
#
#        Economy    Family    Health   Freedom     Trust  Generosity  Year  \
# ...

# %%
pd_happy_alcohol_smoke_internet_no_nan = pd_happy_alcohol_smoke_internet.dropna()
pd_happy_alcohol_smoke_internet_no_nan
# Out:
#       Unnamed: 0                   Country  Happiness Rank  Happiness  \
# 0              0               Switzerland               1     7.5870
# 1              1                   Iceland               2     7.5610
# 2              2                   Denmark               3     7.5270
# 3              3                    Norway               4     7.5220
# 4              4                    Canada               5     7.4270
# ...          ...                       ...             ...        ...
# 1232        1232  Central African Republic             149     3.4759
# 1233        1233                    Rwanda             150     3.3123
# 1234        1234                  Zimbabwe             151     3.2992
# 1235        1235               South Sudan             152     2.8166
# 1236        1236               Afghanistan             153     2.5669
#
#        Economy    Family    Health   Freedom     Trust  Generosity  Year  \
# ...

# %%
pd_happy_alcohol_smoke_internet_no_nan.to_csv("./data/preprocessed_data_happy_incl_region_no_nan.csv")

# %%
until_2018_raw_values = pd.read_csv("./data/until_2018_raw_values.csv", sep= ";")
until_2018_raw_values
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.168690        0.450662
# 1     Afghanistan  2009     4.401778            7.333790        0.552308
# 2     Afghanistan  2010     4.758381            7.386629        0.539075
# 3     Afghanistan  2011     3.831719            7.415019        0.521104
# 4     Afghanistan  2012     3.782938            7.517126        0.520637
# ...           ...   ...          ...                 ...             ...
# 1699     Zimbabwe  2014     4.184451            7.562753        0.765839
# 1700     Zimbabwe  2015     3.703191            7.556052        0.735800
# 1701     Zimbabwe  2016     3.735400            7.538829        0.768425
# 1702     Zimbabwe  2017     3.638300            7.549491        0.754147
# 1703     Zimbabwe  2018     3.616480            7.553395        0.775388
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
until_2018_raw_values_reduced = until_2018_raw_values.iloc[:,0:12]
until_2018_raw_values_2018 = until_2018_raw_values_reduced[(until_2018_raw_values_reduced['Year']==2018)]
until_2018_raw_values_2018
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 10    Afghanistan  2018     2.694303            7.494588        0.507516
# 21        Albania  2018     5.004403            9.412399        0.683592
# 28        Algeria  2018     5.043086            9.557952        0.798651
# 45      Argentina  2018     5.792797            9.809972        0.899912
# 58        Armenia  2018     5.062449            9.119424        0.814449
# ...           ...   ...          ...                 ...             ...
# 1654    Venezuela  2018     5.005663            9.270281        0.886882
# 1667      Vietnam  2018     5.295547            8.783416        0.831945
# 1678        Yemen  2018     3.057514                 NaN        0.789422
# 1690       Zambia  2018     4.041488            8.223958        0.717720
# 1703     Zimbabwe  2018     3.616480            7.553395        0.775388
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
raw_happy_alcohol = pd.merge(until_2018_raw_values_2018, pd_alcohol, how='left', left_on=["Country name",'Year'], right_on=["Entity",'Year'])
raw_happy_alcohol.drop(['Entity', 'GDP per capita, PPP (constant 2017 international $)', 'Continent'], axis=1, inplace=True)
raw_happy_alcohol
# Out:
#     Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0    Afghanistan  2018     2.694303            7.494588        0.507516
# 1        Albania  2018     5.004403            9.412399        0.683592
# 2        Algeria  2018     5.043086            9.557952        0.798651
# 3      Argentina  2018     5.792797            9.809972        0.899912
# 4        Armenia  2018     5.062449            9.119424        0.814449
# ..           ...   ...          ...                 ...             ...
# 131    Venezuela  2018     5.005663            9.270281        0.886882
# 132      Vietnam  2018     5.295547            8.783416        0.831945
# 133        Yemen  2018     3.057514                 NaN        0.789422
# 134       Zambia  2018     4.041488            8.223958        0.717720
# 135     Zimbabwe  2018     3.616480            7.553395        0.775388
#
#      Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
raw_happy_alcohol_smoke = pd.merge(raw_happy_alcohol, filtered_pd_smoke, how='left', left_on=["Code",'Year'], right_on=["Code",'Year'])
raw_happy_alcohol_smoke.drop(['Entity'], axis=1, inplace=True)
raw_happy_alcohol_smoke
# Out:
#     Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0    Afghanistan  2018     2.694303            7.494588        0.507516
# 1        Albania  2018     5.004403            9.412399        0.683592
# 2        Algeria  2018     5.043086            9.557952        0.798651
# 3      Argentina  2018     5.792797            9.809972        0.899912
# 4        Armenia  2018     5.062449            9.119424        0.814449
# ..           ...   ...          ...                 ...             ...
# 131    Venezuela  2018     5.005663            9.270281        0.886882
# 132      Vietnam  2018     5.295547            8.783416        0.831945
# 133        Yemen  2018     3.057514                 NaN        0.789422
# 134       Zambia  2018     4.041488            8.223958        0.717720
# 135     Zimbabwe  2018     3.616480            7.553395        0.775388
#
#      Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
raw_happy_alcohol_smoke_internet = pd.merge(raw_happy_alcohol_smoke, pd_internet_unpivot, how='left', left_on=['Code','Year'], right_on=['Code','Year'])
raw_happy_alcohol_smoke_internet
# Out:
#     Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0    Afghanistan  2018     2.694303            7.494588        0.507516
# 1        Albania  2018     5.004403            9.412399        0.683592
# 2        Algeria  2018     5.043086            9.557952        0.798651
# 3      Argentina  2018     5.792797            9.809972        0.899912
# 4        Armenia  2018     5.062449            9.119424        0.814449
# ..           ...   ...          ...                 ...             ...
# 131    Venezuela  2018     5.005663            9.270281        0.886882
# 132      Vietnam  2018     5.295547            8.783416        0.831945
# 133        Yemen  2018     3.057514                 NaN        0.789422
# 134       Zambia  2018     4.041488            8.223958        0.717720
# 135     Zimbabwe  2018     3.616480            7.553395        0.775388
#
#      Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
raw_happy_alcohol_smoke_internet.rename(columns = {'Country name':'Country','Life Ladder':'Happiness','Log GDP per capita':'Economy',
                                                              'Healthy life expectancy at birth':'Health','Freedom to make life choices':'Freedom','Perceptions of corruption':'Corruption',
                                                              'Confidence in national government':'Government',
                                                              'Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)':'Alcohol',
                                                              'Population (historical estimates)':'Population','Prevalence of current tobacco use (% of adults)':'Tobacco',
                                                              'Individuals using the Internet (% of population)':'Internet'
                                                              }, inplace = True)

fig = msno.matrix(raw_happy_alcohol_smoke_internet)
fig_copy = fig.get_figure()
fig_copy.savefig('raw_2018_missing_values.png', bbox_inches = 'tight')

# %%
raw_happy_alcohol_smoke_internet = raw_happy_alcohol_smoke_internet.dropna()
raw_happy_alcohol_smoke_internet
# Out:
#            Country  Year  Happiness    Economy  Social support     Health  \
# 1          Albania  2018   5.004403   9.412399        0.683592  68.699997
# 3        Argentina  2018   5.792797   9.809972        0.899912  68.800003
# 4          Armenia  2018   5.062449   9.119424        0.814449  66.900002
# 5        Australia  2018   7.176993  10.721021        0.940137  73.599998
# 6          Austria  2018   7.396002  10.741893        0.911668  73.000000
# ..             ...   ...        ...        ...             ...        ...
# 128  United States  2018   6.882685  10.922465        0.903856  68.300003
# 129        Uruguay  2018   6.371715   9.959661        0.917316  69.000000
# 130     Uzbekistan  2018   6.205460   8.773365        0.920821  65.099998
# 134         Zambia  2018   4.041488   8.223958        0.717720  55.299999
# 135       Zimbabwe  2018   3.616480   7.553395        0.775388  55.599998
#
#       Freedom  Generosity  Corruption  Positive affect  Negative affect  \
# ...

# %%
raw_happy_alcohol_smoke_internet.to_csv("./data/preprocessed_raw_2018_no_nan.csv", index=False)
